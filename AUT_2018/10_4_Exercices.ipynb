# %% [markdown]
# "* __Note__:<p style="color:red;">Dans les présents exercices, les termes employés pour désigner des personnes sont pris au sens générique; ils ont à la fois valeur d’un féminin et d’un masculin.</p>

# %% [markdown]
# # Exercice_1
# Lisez les brefs rappels de quelques notions de l'assurance non-vie. Ensuite, calculez la prime pure pour chaque assuré de notre base de données `eq_2`.

# %% [markdown]
# ### Exposition au risque
# L'exposition au risque correspond à la période de temps
# (en jours, en heure, etc.), sur une durée donnée, pour lequel l'assuré était couvert par l'assurance.
# Par exemple, pour l'année 2007, un assuré sera couvert pour 180 jours si un assuré possède une
# assurance commençant le 1er juillet 2006 jusqu'au 30 juin 2007.
#
# <p style="font-size:80%;">**Note**: Définition provenant des notes du cours ACT2040 de Jean-Philippe Boucher</p>
# ### Fréquence
#
# Il s'agit du nombre de sinistres observés par unité d'exposition.
#
# $$\text{Fréquence}=\frac{\text{nombre de sinistres}}{\text{exposition}}$$
#
# ### Sévérité
# Il s'agit du coût moyen d'un sinistre.
# $$\text{Sévérité}=\frac{\text{Coûts totaux enregistrés}}{\text{nombre de sinistres}}$$
#
# ### Prime pure
# Il s'agit du coût moyen d'assurance par unité d'exposition.
#
#
# \begin{split}
# \text{Prime pure} & =\frac{\text{Coûts totaux enregistrés}}{\text{exposition}} \\
#  & = \frac{\text{nombre de sinistres}}{\text{exposition}} \text{X} \frac{\text{Coûts totaux enregistrés}}{\text{nombre de sinistres}}\\
#  & = \text{Fréquence x Sévérité}
# \end{split}

# %% [markdown]
# ## Exercice_2
#
# Lors du _party_ de Noël que votre employeur a organisé, vous rencontrez une charmante des demoiselles* du département des fournitures de bureau qui a été recrutée comme vous il y'a quelques semaines. Elle vous raconte qu'elle a vraiment été occupée au mois de décembre. Car l'entreprise où vous travaillez tient à sa tradition d'envoyer chaque mois une carte d'anniversaire à ses clients que leur mois de naissance est le mois courant.
#
# La tâche de la stagiaire était d'ouvrir un fichier Excel contenant les informations des clients et d'extraire (avec l'option filtrer d'Excel) les infos pertinentes afin de commander le nombre exact de cartes.
#
# En plus, elle doit remplir un tableau suivant:
#
# <style type="text/css">
# 	table.tableizer-table {
# 		font-size: 12px;
# 		border: 1px solid #CCC;
# 		font-family: Arial, Helvetica, sans-serif;
# 	}
# 	.tableizer-table td {
# 		padding: 4px;
# 		margin: 3px;
# 		border: 1px solid #CCC;
# 	}
# 	.tableizer-table th {
# 		background-color: #104E8B;
# 		color: #FFF;
# 		font-weight: bold;
# 	}
# </style>
# <table class="tableizer-table">
# <thead><tr class="tableizer-firstrow"><th>\</th><th>Français</th><th>Anglais</th></tr></thead><tbody>
#  <tr><td>Féminin</td><td>-</td><td>-</td></tr>
#  <tr><td>Masculin</td><td>-</td><td>-</td></tr>
# </tbody></table>
#
# Qui contient le nombre de clients féminins et masculins, des anglophones ainsi que des anglophones.
#
# Vous vous rappelez alors que vous avez déjà consulté une base de données qui contient les mêmes informations que le fichier Excel, et en plus vous avez appris dans le cours ACT3035 comment extraire des données avec SAS très rapidement!
#
# # a)
# D'abord, dans la base donnée avec laquelle nous avons fait les exemples ci-dessus `eq_2`, faites une extraction des données des clients nés en ce mois (mois courant).
#
# # b)
# Maintenant que vous avez les données de la question_1, vous voulez encore être plus gentil et fournir à la fille un tableau contenant les informations dont elle a besoin afin de commander le bon nombre de cartes.
#
# Utilisez les variables pertinentes à cet exercice.

# %% [markdown]
# # Exercice_3

# %% [markdown]
# Supposons qu'il a été démontré que les végétaliens et végétaliens sont très prudents, ces derniers sont rarement impliqués dans des accidents de la route. L'assureur pour lequel vous travaillez décide alors de donner un rabais à ces assurés. Pour végétaliens, le rabais est de l'ordre de 15%, alors que pour les végétariens, il est de 10%.
# Créez une nouvelle variable qui indique le rabais appliqué à chaque assuré de votre base de données.
#
# **Indice**

# %%
Data ;
    set ...;    
    if alimentation='Végétalien' ...;
        
    else if alimentation='Végétarien' ...;
    
    format rabais percent10.;
    keep numeropol alimentation rabais;
run;
proc print ...;
run;
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="SAS 9.4" name="generator"/>
# <title>SAS Output</title>
# <style>
# /*<![CDATA[*/
# .body.c > table, .body.c > pre, .body.c div > table,
# .body.c div > pre, .body.c > table, .body.c > pre,
# .body.j > table, .body.j > pre, .body.j div > table,
# .body.j div > pre, .body.j > table, .body.j > pre,
# .body.c p.note, .body.c p.warning, .body.c p.error, .body.c p.fatal,
# .body.j p.note, .body.j p.warning, .body.j p.error, .body.j p.fatal,
# .body.c > table.layoutcontainer, .body.j > table.layoutcontainer { margin-left: auto; margin-right: auto }
# .layoutregion.l table, .layoutregion.l pre, .layoutregion.l p.note,
# .layoutregion.l p.warning, .layoutregion.l p.error, .layoutregion.l p.fatal { margin-left: 0 }
# .layoutregion.c table, .layoutregion.c pre, .layoutregion.c p.note,
# ...

# %% [markdown]
# # Exercice_4

# %% [markdown]
# Lorsque vous faites un modèle qui prédit le nombre de sinistres dans votre BD `eq_2`, vous constatez que le nombre de sinistres est très différent des années pour les clients qui précèdent le 1999-10-31. Lorsque vous en parlez à votre superviseur, ce dernier vous informe qu'à cette date, l'entreprise pour laquelle vous travaillez actuellement a fait l’acquisition d'un autre petit assureur. Et que toutes les données ont été fusionnées à cette date. Vous êtes très curieux et vous voulez appliquer votre modèle sur les données dont la police d'assurance débute après cette date.
#
# Scindez votre base de données en deux en se basant sur la date début de la police qui est effective après le 1999-10-31.
