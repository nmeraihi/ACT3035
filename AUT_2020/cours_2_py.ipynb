# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd

# %%
df=pd.read_csv("https://saaq.gouv.qc.ca/donnees-ouvertes/rapports-accident/rapports-accident-2019.csv")

# %%
df.head()

# %%
# list(df.columns)
df.columns

# %%
df.describe()

# %%
df.shape

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# lire les données
# df=pd.read_csv("")

# %%
# écrire les données
# df.to_json("")

# %%
df[["NB_MORTS","NB_BLESSES_GRAVES"]].head()

# %%
df[["NB_MORTS","NB_BLESSES_GRAVES"]].tail()

# %%
df[["NB_MORTS","NB_BLESSES_GRAVES"]].shape

# %%
# list(df.columns)

# %%
df_nb_morts_plus_grand_egale_1=df[df["NB_MORTS"]>=2]

# %%
df_nb_morts_plus_grand_egale_1.head()

# %%
# df[(df["NB_MORTS"]>=2)|(df["JR_SEMN_ACCDN"]=="LU")]

# %%
df.iloc[5:2055,0:5]

# %%
df_bitcoin=pd.read_csv("https://raw.githubusercontent.com/nmeraihi/data/master/bitcoin_price.csv")

# %%
df_bitcoin.head()

# %%
df_bitcoin.plot()

# %%
df_bitcoin["close_price_5perce"]=df_bitcoin["Close Price"]*1.05

# %%
df_bitcoin.head()

# %%
df_bitcoin["Close Price"].mean()

# %%
df.head(2)

# %%
df[["NB_MORTS", "JR_SEMN_ACCDN"]].groupby("JR_SEMN_ACCDN").mean()

# %%
df["ACCDN_PRES_DE"].str.lower()

# %%
df["ACCDN_PRES_DE"].str.len()

# %%
def signe(x):
  if x>0:
    return "positif"

# %%
signe(3)

# %%
signe(-3)

# %%
def signe(x):
  if x>0:
    return "positif"
  elif x<0:
    return "negatif"

# %%
signe(15)

# %%
signe(-3)

# %%
def signe(x):
  if x>0:
    return "positif"
  elif x<0:
    return "negatif"
  elif x==0:
    return "ni pos ni negatif"

# %%
signe(15)

# %%
signe(-15)

# %%
signe(0)

# %%
import numpy as np

# %%
for i in np.arange(5):
  print(i)

# %%
x=np.array([1,6,2])
y=np.array([1,4,2])

# %%
x+y

# %%
len(x)

# %%
np.asmatrix(np.arange(1,5).reshape(2,2))

# %%
np.asmatrix(np.arange(1,5).reshape(2,2).transpose())

# %%
np.random.seed(3035)
x=np.random.normal(size=100)
y=np.random.normal(size=100)

# %%
y.mean(), y.var(), y.std(), np.sqrt(y.var())

# %%
import seaborn as sns

# %%
graph=sns.jointplot(x, y, kind="scatter")
graph.set_axis_labels(xlabel="Axe des x", ylabel="axe des y");

# %%
df_boston=pd.read_csv("https://raw.githubusercontent.com/nmeraihi/data/master/islr/Boston.csv")

# %%
df_boston.head()

# %%
df_boston=df_boston.iloc[:,1:]

# %%
x=df_boston["lstat"]

# %%
y=df_boston["medv"]

# %%
import statsmodels.api as sm

# %%
model_1=sm.OLS(y, x)

# %%
model_1_fi=model_1.fit()

# %%
model_1_fi.summary()
